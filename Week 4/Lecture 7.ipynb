# %% [markdown]
# # ISA 414 - Managing Big Data
# ## Lecture 7 - Data Collection
# ### Web Scraping (Part I)

# %% [markdown]
# #### Slide 25: Make sure you install the *request* module first by running **pip install requests** in the Terminal.

# %% [markdown]
# #### Slide 27

# %%
import requests

r = requests.get("http://www.espn.com/nfl/superbowl/history/winners")
html_code = r.text
print(html_code)
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="https://www.facebook.com/2008/fbml">
# <head>
#
# <script>
# (function redirectToHttpIfHttps() {
#    var win      = typeof window !== 'undefined' && window,
#        location = win && win.location,
#        protocol = location && location.protocol;
#
#    if (protocol === 'https:' && !false) {
#         location.href = location.href.replace('https://', 'http://');
#    }
# })();
# </script><meta charset="iso-8859-1">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# <link rel="icon" sizes="any" mask href="https://a.espncdn.com/favicon.ico">
# <meta name="theme-color" content="#CC0000">
# <script type="text/javascript">
#     if(true && navigator && navigator.userAgent.toLowerCase().indexOf("teamstream") >= 0) {
#         window.location = 'http://m.espn.com/mobilecache/general/apps/sc';
#     }
# </script><title>Super Bowl Winners and Results - Super Bowl History - National Football League - ESPN</title>
# ...

# %% [markdown]
# #### slide 30

# %%
import re

matches = re.finditer("<td>", html_code)
open_tags = [m.start(0) for m in matches]

# %% [markdown]
# #### slide 31

# %%
matches = re.finditer("</td>", html_code)
close_tags = [m.start(0) for m in matches]

# %%
# removing the first close tag
close_tags.pop(0)
# Out:
# 9003

# %% [markdown]
# #### slide 32

# %%
web_data = []
for i in range(len(open_tags)):
    web_data.append(html_code[open_tags[i] + 4:close_tags[i]])

web_data
# Out:
# ['NO.',
#  'DATE',
#  'SITE',
#  'RESULT',
#  'I',
#  'Jan. 15, 1967',
#  'Los Angeles Memorial Coliseum',
#  'Green Bay 35, Kansas City 10',
#  'II',
#  'Jan. 14, 1968',
#  'Orange Bowl (Miami)',
#  'Green Bay 33, Oakland 14',
#  'III',
#  'Jan. 12, 1969',
#  'Orange Bowl (Miami)',
#  'New York Jets 16, Baltimore 7',
#  'IV',
#  'Jan. 11, 1970',
#  'Tulane Stadium (New Orleans)',
#  'Kansas City 23, Minnesota 7',
#  'V',
#  'Jan. 17, 1971',
#  'Orange Bowl (Miami)',
#  'Baltimore 16, Dallas 13',
#  'VI',
#  'Jan. 16, 1972',
#  'Tulane Stadium (New Orleans)',
#  'Dallas 24, Miami 3',
#  'VII',
#  'Jan. 14, 1973',
#  'Los Angeles Memorial Coliseum',
#  'Miami 14, Washington 7',
#  'VIII',
#  'Jan. 13, 1974',
#  'Rice Stadium (Houston)',
#  'Miami 24, Minnesota 7',
#  'IX',
#  'Jan. 12, 1975',
#  'Tulane Stadium (New Orleans)',
#  'Pittsburgh 16, Minnesota 6',
#  'X',
#  'Jan. 18, 1976',
#  'Orange Bowl (Miami)',
#  'Pittsburgh 21, Dallas 17',
#  'XI',
#  'Jan. 9, 1977',
# ...

# %% [markdown]
# #### slide 33

# %%
import pandas as pd 

rows = []

# creating a list of lists, each one having 4 elements
for i in range(4, len(web_data), 4):
    rows.append(web_data[i:i+4])

# creating a data frame
df = pd.DataFrame(rows, columns = web_data[0:4])

df
# Out:
#         NO.           DATE                                             SITE  \
# 0         I  Jan. 15, 1967                    Los Angeles Memorial Coliseum
# 1        II  Jan. 14, 1968                              Orange Bowl (Miami)
# 2       III  Jan. 12, 1969                              Orange Bowl (Miami)
# 3        IV  Jan. 11, 1970                     Tulane Stadium (New Orleans)
# 4         V  Jan. 17, 1971                              Orange Bowl (Miami)
# 5        VI  Jan. 16, 1972                     Tulane Stadium (New Orleans)
# 6       VII  Jan. 14, 1973                    Los Angeles Memorial Coliseum
# 7      VIII  Jan. 13, 1974                           Rice Stadium (Houston)
# 8        IX  Jan. 12, 1975                     Tulane Stadium (New Orleans)
# 9         X  Jan. 18, 1976                              Orange Bowl (Miami)
# 10       XI   Jan. 9, 1977                     Rose Bowl (Pasadena, Calif.)
# ...
