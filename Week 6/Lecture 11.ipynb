# %% [markdown]
# # ISA 414 - Managing Big Data
# ## Lecture 11 – Data Collection
# ### Querying Document-Oriented Databases

# %% [markdown]
# #### slide 17: Make sure you install the *pymongo* module first by running te command below in the terminal:
#  pip install 'pymongo[snappy,gssapi,srv,tls]'

# %%
import pandas as pd

df = pd.read_csv("cars.csv")
df
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# #### slide 19

# %%
import pymongo
import certifi

# connecting to MongoDB
# replace PASTE THE COPIED STRING HERE with the string you copied before 
client = pymongo.MongoClient("mongodb://johndoll:abcd1234@cluster0-shard-00-00.8fq8g.mongodb.net:27017,cluster0-shard-00-01.8fq8g.mongodb.net:27017,cluster0-shard-00-02.8fq8g.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-mjwrpm-shard-0&authSource=admin&retryWrites=true&w=majority",  tlsCAFile=certifi.where())

# %% [markdown]
# #### slide 20

# %%
db = client.ISA414
collection = db.cars

# %% [markdown]
# #### slide 21

# %%
# the argument "records" creates a like [{column -> value}, ... , {column -> value}]
data_json = df.to_dict("records")

# inserting the data
collection.insert_many(data_json)

# %% [markdown]
# #### slide 33

# %%
# first query
result = collection.find({"mpg":21})

for document in result:
    print(document)
# Out:
# {'_id': ObjectId('61535a4d13cdbac00905e350'), 'name': 'Mazda RX4', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.62, 'qsec': 16.46, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4, 'color': 'blue'}
# {'_id': ObjectId('61535a4d13cdbac00905e351'), 'name': 'Mazda RX4 Wag', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.875, 'qsec': 17.02, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4}

# %%
# second query
result = collection.find({"mpg":21, "color":"blue"})

for document in result:
    print(document)
# Out:
# {'_id': ObjectId('61535a4d13cdbac00905e350'), 'name': 'Mazda RX4', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.62, 'qsec': 16.46, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4, 'color': 'blue'}

# %% [markdown]
# #### slide 34

# %%
# first query
result = collection.find({"mpg":{"$gt":20}})

for document in result:
    print(document)
# Out:
# {'_id': ObjectId('61535a4d13cdbac00905e350'), 'name': 'Mazda RX4', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.62, 'qsec': 16.46, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4, 'color': 'blue'}
# {'_id': ObjectId('61535a4d13cdbac00905e351'), 'name': 'Mazda RX4 Wag', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.875, 'qsec': 17.02, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4}
# {'_id': ObjectId('61535a4d13cdbac00905e352'), 'name': 'Datsun 710', 'mpg': 22.8, 'cyl': 4, 'disp': 108.0, 'hp': 93, 'drat': 3.85, 'wt': 2.32, 'qsec': 18.61, 'vs': 1, 'am': 1, 'gear': 4, 'carb': 1}
# {'_id': ObjectId('61535a4d13cdbac00905e353'), 'name': 'Hornet 4 Drive', 'mpg': 21.4, 'cyl': 6, 'disp': 258.0, 'hp': 110, 'drat': 3.08, 'wt': 3.215, 'qsec': 19.44, 'vs': 1, 'am': 0, 'gear': 3, 'carb': 1}
# ...

# %%
# second query
result = collection.find({"mpg":{"$gt":20, "$lt":25}})
for document in result:
    print(document)
# Out:
# {'_id': ObjectId('61535a4d13cdbac00905e350'), 'name': 'Mazda RX4', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.62, 'qsec': 16.46, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4, 'color': 'blue'}
# {'_id': ObjectId('61535a4d13cdbac00905e351'), 'name': 'Mazda RX4 Wag', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.875, 'qsec': 17.02, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4}
# {'_id': ObjectId('61535a4d13cdbac00905e352'), 'name': 'Datsun 710', 'mpg': 22.8, 'cyl': 4, 'disp': 108.0, 'hp': 93, 'drat': 3.85, 'wt': 2.32, 'qsec': 18.61, 'vs': 1, 'am': 1, 'gear': 4, 'carb': 1}
# {'_id': ObjectId('61535a4d13cdbac00905e353'), 'name': 'Hornet 4 Drive', 'mpg': 21.4, 'cyl': 6, 'disp': 258.0, 'hp': 110, 'drat': 3.08, 'wt': 3.215, 'qsec': 19.44, 'vs': 1, 'am': 0, 'gear': 3, 'carb': 1}
# ...

# %% [markdown]
# #### slide 35

# %%
query      = {"name":"Mazda RX4"}
new_values = {"$set":{"mpg":100}}

collection.update_many(query, new_values)

# print all documents after the update
for result in collection.find():
  print(result)
# Out:
# {'_id': ObjectId('61535a4d13cdbac00905e350'), 'name': 'Mazda RX4', 'mpg': 100, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.62, 'qsec': 16.46, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4, 'color': 'blue'}
# {'_id': ObjectId('61535a4d13cdbac00905e351'), 'name': 'Mazda RX4 Wag', 'mpg': 21.0, 'cyl': 6, 'disp': 160.0, 'hp': 110, 'drat': 3.9, 'wt': 2.875, 'qsec': 17.02, 'vs': 0, 'am': 1, 'gear': 4, 'carb': 4}
# {'_id': ObjectId('61535a4d13cdbac00905e352'), 'name': 'Datsun 710', 'mpg': 22.8, 'cyl': 4, 'disp': 108.0, 'hp': 93, 'drat': 3.85, 'wt': 2.32, 'qsec': 18.61, 'vs': 1, 'am': 1, 'gear': 4, 'carb': 1}
# {'_id': ObjectId('61535a4d13cdbac00905e353'), 'name': 'Hornet 4 Drive', 'mpg': 21.4, 'cyl': 6, 'disp': 258.0, 'hp': 110, 'drat': 3.08, 'wt': 3.215, 'qsec': 19.44, 'vs': 1, 'am': 0, 'gear': 3, 'carb': 1}
# ...

# %% [markdown]
# #### slide 36

# %%
collection.delete_many({"cyl":6})

# print all documents after the delete
for result in collection.find():
  print(result)
# Out:
# {'_id': ObjectId('61535a4d13cdbac00905e352'), 'name': 'Datsun 710', 'mpg': 22.8, 'cyl': 4, 'disp': 108.0, 'hp': 93, 'drat': 3.85, 'wt': 2.32, 'qsec': 18.61, 'vs': 1, 'am': 1, 'gear': 4, 'carb': 1}
# {'_id': ObjectId('61535a4d13cdbac00905e354'), 'name': 'Hornet Sportabout', 'mpg': 18.7, 'cyl': 8, 'disp': 360.0, 'hp': 175, 'drat': 3.15, 'wt': 3.44, 'qsec': 17.02, 'vs': 0, 'am': 0, 'gear': 3, 'carb': 2}
# {'_id': ObjectId('61535a4d13cdbac00905e356'), 'name': 'Duster 360', 'mpg': 14.3, 'cyl': 8, 'disp': 360.0, 'hp': 245, 'drat': 3.21, 'wt': 3.57, 'qsec': 15.84, 'vs': 0, 'am': 0, 'gear': 3, 'carb': 4}
# {'_id': ObjectId('61535a4d13cdbac00905e357'), 'name': 'Merc 240D', 'mpg': 24.4, 'cyl': 4, 'disp': 146.7, 'hp': 62, 'drat': 3.69, 'wt': 3.19, 'qsec': 20.0, 'vs': 1, 'am': 0, 'gear': 4, 'carb': 2}
# {'_id': ObjectId('61535a4d13cdbac00905e358'), 'name': 'Merc 230', 'mpg': 22.8, 'cyl': 4, 'disp': 140.8, 'hp': 95, 'drat': 3.92, 'wt': 3.15, 'qsec': 22.9, 'vs': 1, 'am': 0, 'gear': 4, 'carb': 2}
# ...
